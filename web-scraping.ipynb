# %%
"""
Web Scraping - Beautiful Soup
"""

# importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# target URL to scrap
url = "https://www.goibibo.com/hotels/hotels-in-shimla-ct/"

# headers
headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    }

# send request to download the data
response = requests.request("GET", url, headers=headers)

# parse the downloaded data
data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true">Hotels in Shimla, 557 Shimla Hotels from ₹300 + upto 30% off</title>
# ...

# %%
# find all the sections with specifiedd class name
cards_data = data.find_all('div', attrs={'class', 'HotelCardstyles__WrapperSectionMetaDiv-sc-1s80tyk-2 cPtMpq'})

# total number of cards
print('Total Number of Cards Found : ', len(cards_data))

# source code of hotel cards
for card in cards_data:
    print(card)
# Out:
# Total Number of Cards Found :  10
# ...

# %%
# extract the hotel name and price per room
for card in cards_data:

    # get the hotel name
    hotel_name = card.find('a',attrs={'class': 'HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 dNdcuN'})
    #print( hotel_name.text)
    # get the room price
    room_price = card.find('p', attrs={'class': 'HotelCardstyles__CurrentPrice-sc-1s80tyk-27 ieJkCi'})
    #print(hotel_name.text, room_price.text)
    
    #get rating of hotel
    hotal_rating = card.find('span', attrs={'class': 'ReviewAndRatingsstyles__AverageReviewText-sc-1nxmeoo-6 iIlkKl'})
    print(hotel_name.text, room_price.text,hotal_rating.text)
# Out:
# Snow Valley Resorts 2747 4.4 / 5
# The Zion Hotel 2642 4.6 / 5
# Hotel Shingar 1870 4.1 / 5
# Hotel Willow Banks 5154 4.1 / 5
# Rocky Knob (Explore World Art in One Property) 2525 4.6 / 5
# Honeymoon Inn 3500 4.5 / 5
# Hotel Surya 2338 3.8 / 5
# Hotel Greenland 1320 3.7 / 5
# Snow Lotus 1763 4.3 / 5
# Summit Le Royale 2123 4 / 5

# %%
# create a list to store the data
scraped_data = []

for card in cards_data:

    # initialize the dictionary
    card_details = {}

    # get the hotel name
    hotel_name = card.find('a',attrs={'class': 'HotelCardstyles__HotelNameSeoAnchor-sc-1s80tyk-12 dNdcuN'})

    # get the room price
    room_price = card.find('p', attrs={'class': 'HotelCardstyles__CurrentPrice-sc-1s80tyk-27 ieJkCi'})

    #get rating of hotel
    hotal_rating = card.find('span', attrs={'class': 'ReviewAndRatingsstyles__AverageReviewText-sc-1nxmeoo-6 iIlkKl'})
        
    # add data to the dictionary
    card_details['Hotel Name'] = hotel_name.text
    card_details['Room Price'] = room_price.text
    card_details['Hotal Rating'] = hotal_rating.text

    # append the scraped data to the list
    scraped_data.append(card_details)

# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(scraped_data)

# save the scraped data as CSV file
dataFrame.to_csv('hotels_data.csv', index=False)
